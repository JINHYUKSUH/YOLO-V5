# %% [markdown]
# https://yeko90.tistory.com/entry/ultralytics-yolov5-tutorial#google_vignette
# https://applecider1002.tistory.com/170
# https://blog.naver.com/PostView.naver?blogId=s_holmes25&logNo=222152973262

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xflruvxrRKGbU1KDQxfK")
project = rf.workspace("joseph-nelson").project("pistols")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pistols-1 in yolov5pytorch:: 100%|█████████████| 5945/5945 [00:01<00:00, 4756.68it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\noname'

# %%
import os
os.chdir('C:\\Users\\noname\\yolov5')

# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/40.4 kB ? eta -:--:--
#      ---------------------------------------- 40.4/40.4 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#    ----------------------- ---------------- 122.9/207.3 kB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 194.6/207.3 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 207.3/207.3 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.5 MB 1.7 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.5 MB 1.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.5 MB 845.5 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/2.5 MB 787.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/2.5 MB 798.5 kB/s eta 0:00:03
# ...

# %%
file_path = "C:\\Users\\noname\\Pistols-1\\data.yaml"

# 파일 열기 및 내용 출력
with open(file_path, 'r') as file:
    data = file.read()
    print(data)
# Out:
# names:
# - pistol
# nc: 1
# train: C:\Users\noname\Pistols-1\train.txt
# val: C:\Users\noname\Pistols-1\val.txt

# %%
from glob import glob

img_list = glob('C:\\Users\\noname\\yolov5\\Pistols-1\\export\\images\\*.jpg')

print(len(img_list)) #이미지 갯수
# Out:
# 2971

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))
# Out:
# 2376 595

# %%
with open('C:\\Users\\noname\\yolov5\\Pistols-1\\train.txt', 'w') as f:
  f.write('\n'.join(train_img_list) + '\n')

with open('C:\\Users\\noname\\yolov5\\Pistols-1\\val.txt', 'w') as f:
  f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml

with open('C:\\Users\\noname\\yolov5\\Pistols-1\\data.yaml', 'r') as f:
  data = yaml.load(f, Loader=yaml.FullLoader)

print(data)

data['train'] = 'C:\\Users\\noname\\yolov5\\Pistols-1\\train.txt'
data['val'] = 'C:\\Users\\noname\\yolov5\\Pistols-1\\val.txt'

with open('C:\\Users\\noname\\yolov5\\Pistols-1\\data.yaml', 'w') as f:
  yaml.dump(data, f)

print(data)
# Out:
# {'names': ['pistol'], 'nc': 1, 'train': 'Pistols-1/train/images', 'val': 'Pistols-1/valid/images'}
# {'names': ['pistol'], 'nc': 1, 'train': 'C:\\Users\\noname\\yolov5\\Pistols-1\\train.txt', 'val': 'C:\\Users\\noname\\yolov5\\Pistols-1\\val.txt'}

# %%
# !python train.py --img 416 --batch 16 --epochs 10 --data /Users/Noname/Pistols-1/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# ^C
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# [Errno 2] No such file or directory: 'C:\\Users\\noname\\yolov5\\runs\\train\\gun_yolov5s_results2\\labels_correlogram.jpg'
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/Users/Noname/Pistols-1/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=gun_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# ...

# %%
from IPython.display import Image
import os

val_img_path = val_img_list[151]

# !python detect.py --weights /Users/noname/yolov5/runs/train/gun_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source "{val_img_path}"

Image(os.path.join('runs/detect/exp', os.path.basename(val_img_path)))
# Out:
# detect: weights=['/Users/noname/yolov5/runs/train/gun_yolov5s_results/weights/best.pt'], source=C:\Users\noname\yolov5\Pistols-1\export\images\armas (2967)_jpg.rf.3d3cb409d02f992b4509b9c53109456f.jpg, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: not a git repository (or any of the parent directories): .git
# YOLOv5  2024-4-8 Python-3.9.18 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
from IPython.display import Image
import os

test_img_path = 'C:\\Users\\noname\\Pistols-1\\test_set\\pistol_2.png'

# !python detect.py --weights /Users/noname/yolov5/runs/train/gun_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source "{test_img_path}"

Image(os.path.join('runs/detect/exp', os.path.basename(val_img_path)))
# Out:
# python: can't open file 'C:\Users\noname\detect.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 test_img_path = 'C:\\Users\\noname\\Pistols-1\\test_set\\pistol_2.png'
#       6 get_ipython().system('python detect.py --weights /Users/noname/yolov5/runs/train/gun_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source "{test_img_path}"')
# ----> 8 Image(os.path.join('runs/detect/exp', os.path.basename(val_img_path)))
#
# NameError: name 'val_img_path' is not defined
